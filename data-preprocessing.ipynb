# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib as jl

# %%
df=pd.read_csv('/kaggle/input/students-performance-in-exams/StudentsPerformance.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#separation of numerical and categorical data
numerical_data_cols= df.select_dtypes(exclude=['object'])
                                    
print(numerical_data_cols)
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
numerical_data_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   math score     1000 non-null   int64
#  1   reading score  1000 non-null   int64
#  2   writing score  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
categorical_data_cols= df.select_dtypes(include=['object'])
categorical_data_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
categorical_data_cols
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
list(data['parental level of education'].unique())categorical_data_cols['gender'].value_counts()
# Out:
#   Cell In[9], line 1
#     list(data['parental level of education'].unique())categorical_data_cols['gender'].value_counts()
#                                                       ^
# SyntaxError: invalid syntax

# %%
#encoding
nominaldata_ohe = OneHotEncoder(sparse = False)
nominaldata_ohe.fit_transform(categorical_data_cols[['gender']])

# %%
jl.dump(nominaldata_ohe, 'nominaldata_ohe.pkl')

# %%
#ordinal encoding
list(categorical_data_cols['parental level of education'].unique())

# %%
parental_education = ['some high school', 'high school', 'some college', "associate's degree", "bachelor's degree", "master's degree"]

# %%
oe = OrdinalEncoder(categories = [parental_education])
oe.fit_transform(categorical_data_cols[['parental level of education']])[:5]

# %%
# Calculate average of all test results
numerical_data_cols['mean score']=numerical_data_cols.mean(axis = 1)

# Drop math score, reading score and writing score
numerical_data_cols=numerical_data_cols.drop(['math score', 'reading score', 'writing score'], axis = 1)

# Show first 5 rows of new dataframe
numerical_data_cols.head()
# Out:
#    mean score
# 0   72.666667
# 1   82.333333
# 2   92.666667
# 3   49.333333
# 4   76.333333

# %%
#scaling
ss=StandardScaler().set_output(transform="pandas")
ss.fit(numerical_data_cols)
# Out:
# StandardScaler()

# %%
ss.transform(numerical_data_cols)
# Out:
# array([[ 0.34357423],
#        [ 1.0219275 ],
#        [ 1.74706375],
#        [-1.2938302 ],
#        [ 0.60088064],
#        [ 0.67105512],
#        [ 1.67688927],
#        [-1.90200899],
#        [-0.19443008],
#        [-1.2938302 ],
#        [-0.91956633],
#        [-1.59791959],
#        [ 0.36696572],
#        [ 0.39035722],
#        [-0.9897408 ],
#        [ 0.4371402 ],
#        [ 1.39619137],
#        [-2.93123463],
#        [-1.62131109],
#        [-0.7090429 ],
#        [-0.1242556 ],
#        [ 0.1564423 ],
#        [-1.22365572],
#        [ 0.27339976],
#        [ 0.50731468],
#        [ 0.36696572],
#        [-0.59208544],
#        [ 0.17983379],
#        [ 0.03948484],
#        [ 0.08626782],
#        [ 0.32018274],
#        [-0.33477903],
#        [-0.24121306],
#        [-1.94879197],
#        [ 1.46636584],
#        [ 0.88157855],
#        [ 0.81140407],
#        [-0.7090429 ],
#        [ 1.16227645],
#        [-0.77921738],
#        [-0.77921738],
# ...
